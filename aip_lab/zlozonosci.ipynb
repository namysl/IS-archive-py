# %%
import random
import time
import matplotlib.pyplot as plt
import pylab

# %%
def insertion(lista):
    """opt: n ; śr/pes: O(n^2)"""
    
    n = len(lista)
    for i in range(1, n):
        klucz = lista[i]
        j = i - 1
        while j >= 0 and lista[j] > klucz:
            lista[j+1] = lista[j]
            j -= 1
        lista[j+1] = klucz
    return lista

# %%
# 10000
list_best10000 = [x for x in range(10000)]
list_avg10000 = [random.randint(1, 10000) for x in range(10000)]
list_worst10000 = [x for x in range(10000, 0, -1)]

# 5000
list_best1000 = [x for x in range(5000)]
list_avg1000 = [random.randint(1, 5000) for x in range(5000)]
list_worst1000 = [x for x in range(5000, 0, -1)]

# 250
list_best100 = [x for x in range(250)]
list_avg100 = [random.randint(1, 250) for x in range(250)]
list_worst100 = [x for x in range(250, 0, -1)]

# %%
# 10000
"""BEST CASE"""
insertion_time_best10000 = [0]
len_insertion_best10000 = [0]

istart1_best10000 = time.clock()
insertion(list_best10000)
iend1_best10000 = time.clock()
insertion_time_best10000.append(iend1_best10000 - istart1_best10000)
len_insertion_best10000.append(len(list_best10000))

print(insertion_time_best10000[1])

plt.xlabel('Rozmiar danych') 
plt.ylabel('Czas') 
plt.plot(len_insertion_best10000, insertion_time_best10000, label ='Insertion Sort - przypadek optymistyczny') 
plt.grid() 
plt.legend() 
plt.show() 

"""AVERAGE CASE"""
insertion_time10000 = [0]
len_insertion10000 = [0]

istart110000 = time.clock()
insertion(list_avg10000)
iend110000 = time.clock()
insertion_time10000.append(iend110000 - istart110000)
len_insertion10000.append(len(list_avg10000))

print(insertion_time10000[1])

plt.xlabel('Rozmiar danych') 
plt.ylabel('Czas') 
plt.plot(len_insertion10000, insertion_time10000, label ='Insertion Sort - przypadek średni') 
plt.grid() 
plt.legend() 
plt.show() 

"""WORST CASE"""
insertion_time_worst10000 = [0]
len_insertion_worst10000 = [0]

istart1_worst10000 = time.clock()
insertion(list_worst10000)
iend1_worst10000 = time.clock()
insertion_time_worst10000.append(iend1_worst10000 - istart1_worst10000)
len_insertion_worst10000.append(len(list_worst10000))

print(insertion_time_worst10000[1])

plt.xlabel('Rozmiar danych') 
plt.ylabel('Czas') 
plt.plot(len_insertion_worst10000, insertion_time_worst10000, label ='Insertion Sort - przypadek pesymistyczny')

plt.grid() 
plt.legend() 
plt.show() 

# insertion 10000
fig = pylab.figure(figsize=[6, 5])
pylab.plot(len_insertion_best10000, insertion_time_best10000, label = 'przypadek optymistyczny')
pylab.plot(len_insertion10000, insertion_time10000, label = 'przypadek średni')
pylab.plot(len_insertion_worst10000, insertion_time_worst10000, label = 'przypadek pesymistyczny')
pylab.legend(loc = 'best')
pylab.xlabel('rozmiar danych')
pylab.ylabel('czas')
pylab.title('Insertion Sort\nrozmiar danych: 10000')
pylab.grid()
pylab.show()
# Out:
# 0.0020300000000000873
# 3.7532900000000002
# 7.332330999999999

# %%
# 1000
"""BEST CASE"""
insertion_time_best1000 = [0]
len_insertion_best1000 = [0]

# insertion_small
istart1_best1000 = time.clock()
insertion(list_best1000)
iend1_best1000 = time.clock()
insertion_time_best1000.append(iend1_best1000 - istart1_best1000)
len_insertion_best1000.append(len(list_best1000))

print(insertion_time_best1000[1])

plt.xlabel('Rozmiar danych') 
plt.ylabel('Czas') 
plt.plot(len_insertion_best1000, insertion_time_best1000, label ='Insertion Sort - przypadek optymistyczny') 
plt.grid() 
plt.legend() 
plt.show() 

"""AVERAGE CASE"""
insertion_time1000 = [0]
len_insertion1000 = [0]

istart11000 = time.clock()
insertion(list_avg1000)
iend11000 = time.clock()
insertion_time1000.append(iend11000 - istart11000)
len_insertion1000.append(len(list_avg1000))

print(insertion_time1000[1])

plt.xlabel('Rozmiar danych') 
plt.ylabel('Czas') 
plt.plot(len_insertion1000, insertion_time1000, label ='Insertion Sort - przypadek średni') 
plt.grid() 
plt.legend() 
plt.show() 

"""WORST CASE"""
insertion_time_worst1000 = [0]
len_insertion_worst1000 = [0]

# insertion_small
istart1_worst1000 = time.clock()
insertion(list_worst1000)
iend1_worst1000 = time.clock()
insertion_time_worst1000.append(iend1_worst1000 - istart1_worst1000)
len_insertion_worst1000.append(len(list_worst1000))

print(insertion_time_worst1000[1])

plt.xlabel('Rozmiar danych') 
plt.ylabel('Czas') 
plt.plot(len_insertion_worst1000, insertion_time_worst1000, label ='Insertion Sort - przypadek pesymistyczny')

plt.grid() 
plt.legend() 
plt.show() 

# insertion 1000
fig = pylab.figure(figsize=[6, 5])
pylab.plot(len_insertion_best1000, insertion_time_best1000, label = 'przypadek optymistyczny')
pylab.plot(len_insertion1000, insertion_time1000, label = 'przypadek średni')
pylab.plot(len_insertion_worst1000, insertion_time_worst1000, label = 'przypadek pesymistyczny')
pylab.legend(loc = 'best')
pylab.xlabel('rozmiar danych')
pylab.ylabel('czas')
pylab.title('Insertion Sort\nrozmiar danych: 5000')
pylab.grid()
pylab.show()
# Out:
# 0.0009679999999985256
# 0.9106389999999998
# 1.7395960000000006

# %%
# 100
"""BEST CASE"""
insertion_time_best100 = [0]
len_insertion_best100 = [0]

# insertion_small
istart1_best100 = time.clock()
insertion(list_best100)
iend1_best100 = time.clock()
insertion_time_best100.append(iend1_best100 - istart1_best100)
len_insertion_best100.append(len(list_best100))

print(insertion_time_best100[1])

plt.xlabel('Rozmiar danych') 
plt.ylabel('Czas') 
plt.plot(len_insertion_best100, insertion_time_best100, label ='Insertion Sort - przypadek optymistyczny') 
plt.grid() 
plt.legend() 
plt.show() 

"""AVERAGE CASE"""
insertion_time100 = [0]
len_insertion100 = [0]

istart1100 = time.clock()
insertion(list_avg100)
iend1100 = time.clock()
insertion_time100.append(iend1100 - istart1100)
len_insertion100.append(len(list_avg100))

print(insertion_time100[1])

plt.xlabel('Rozmiar danych') 
plt.ylabel('Czas') 
plt.plot(len_insertion100, insertion_time100, label ='Insertion Sort - przypadek średni') 
plt.grid() 
plt.legend() 
plt.show() 

"""WORST CASE"""
insertion_time_worst100 = [0]
len_insertion_worst100 = [0]

# insertion_small
istart1_worst100 = time.clock()
insertion(list_worst100)
iend1_worst100 = time.clock()
insertion_time_worst100.append(iend1_worst100 - istart1_worst100)
len_insertion_worst100.append(len(list_worst100))

print(insertion_time_worst100[1])

plt.xlabel('Rozmiar danych') 
plt.ylabel('Czas') 
plt.plot(len_insertion_worst100, insertion_time_worst100, label ='Insertion Sort - przypadek pesymistyczny')

plt.grid() 
plt.legend() 
plt.show() 

# insertion 100
fig = pylab.figure(figsize=[6, 5])
pylab.plot(len_insertion_best100, insertion_time_best100, label = 'przypadek optymistyczny')
pylab.plot(len_insertion100, insertion_time100, label = 'przypadek średni')
pylab.plot(len_insertion_worst100, insertion_time_worst100, label = 'przypadek pesymistyczny')
pylab.legend(loc = 'best')
pylab.xlabel('rozmiar danych')
pylab.ylabel('czas')
pylab.title('Insertion Sort\nrozmiar danych: 250')
pylab.grid()
pylab.show()
# Out:
# 7.300000000043383e-05
# 0.0018700000000002603
# 0.0036989999999974543

# %%
def merge(lista):
    """opt/śr/pes: O(n log n)"""
    n = len(lista)
    if n <= 1:
        return lista
    else:
        podzial = n // 2
        lewa = lista[:podzial]
        prawa = lista[podzial:]

        merge(lewa)
        merge(prawa)

        i = 0
        j = 0
        k = 0
        while i < len(lewa) and j < len(prawa):
            if lewa[i] < prawa[j]:
                lista[k] = lewa[i]
                i+=1
            else:
                lista[k] = prawa[j]
                j+=1
            k+=1

        while i < len(lewa):
            lista[k] = lewa[i]
            i+=1
            k+=1
        
        while j < len(prawa):
            lista[k] = prawa[j]
            j+=1
            k+=1   
        return lista

# %%
# 10000
"""BEST CASE"""
merge_time_best10000 = [0]
len_merge_best10000 = [0]

mstart1_best10000 = time.clock()
merge(list_best10000)
mend1_best10000 = time.clock()
merge_time_best10000.append(mend1_best10000 - mstart1_best10000)
len_merge_best10000.append(len(list_best10000))

print(merge_time_best10000[1])

plt.xlabel('Rozmiar danych') 
plt.ylabel('Czas') 
plt.plot(len_merge_best10000, merge_time_best10000, label ='Merge Sort - przypadek optymistyczny') 
plt.grid() 
plt.legend() 
plt.show() 

"""AVERAGE CASE"""
merge_time10000 = [0]
len_merge10000 = [0]

mstart10000 = time.clock()
merge(list_avg10000)
mend10000 = time.clock()
merge_time10000.append(mend10000 - mstart10000)
len_merge10000.append(len(list_avg10000))

print(merge_time10000[1])

plt.xlabel('Rozmiar danych') 
plt.ylabel('Czas') 
plt.plot(len_merge10000, merge_time10000, label ='Merge Sort - przypadek średni') 
plt.grid() 
plt.legend() 
plt.show() 

"""WORST CASE"""
merge_time_worst10000 = [0]
len_merge_worst10000 = [0]

# merge_small
mstart1_worst10000 = time.clock()
merge(list_worst10000)
mend1_worst10000 = time.clock()
merge_time_worst10000.append(mend1_worst10000 - mstart1_worst10000)
len_merge_worst10000.append(len(list_worst10000))

print(merge_time_worst10000[1])

plt.xlabel('Rozmiar danych') 
plt.ylabel('Czas') 
plt.plot(len_merge_worst10000, merge_time_worst10000, label ='merge Sort - przypadek pesymistyczny')

plt.grid() 
plt.legend() 
plt.show() 

# merge 10000
fig = pylab.figure(figsize=[6, 5])
pylab.plot(len_merge_best10000, merge_time_best10000, label = 'przypadek optymistyczny')
pylab.plot(len_merge10000, merge_time10000, label = 'przypadek średni')
pylab.plot(len_merge_worst10000, merge_time_worst10000, label = 'przypadek pesymistyczny')
pylab.legend(loc = 'best')
pylab.xlabel('rozmiar danych')
pylab.ylabel('czas')
pylab.title('merge Sort\nrozmiar danych: 10000')
pylab.grid()
pylab.show()
# Out:
# 0.03876600000000252
# 0.03665900000000022
# 0.03515200000000007

# %%
# 1000
"""BEST CASE"""
merge_time_best1000 = [0]
len_merge_best1000 = [0]

mstart1_best1000 = time.clock()
merge(list_best1000)
mend1_best1000 = time.clock()
merge_time_best1000.append(mend1_best1000 - mstart1_best1000)
len_merge_best1000.append(len(list_best1000))

print(merge_time_best1000[1])

plt.xlabel('Rozmiar danych') 
plt.ylabel('Czas') 
plt.plot(len_merge_best1000, merge_time_best1000, label ='Merge Sort - przypadek optymistyczny') 
plt.grid() 
plt.legend() 
plt.show() 

"""AVERAGE CASE"""
merge_time1000 = [0]
len_merge1000 = [0]

mstart1000 = time.clock()
merge(list_avg1000)
mend1000 = time.clock()
merge_time1000.append(mend1000 - mstart1000)
len_merge1000.append(len(list_avg1000))

print(merge_time1000[1])

plt.xlabel('Rozmiar danych') 
plt.ylabel('Czas') 
plt.plot(len_merge1000, merge_time1000, label ='Merge Sort - przypadek średni') 
plt.grid() 
plt.legend() 
plt.show() 

"""WORST CASE"""
merge_time_worst1000 = [0]
len_merge_worst1000 = [0]

# merge_small
mstart1_worst1000 = time.clock()
merge(list_worst1000)
mend1_worst1000 = time.clock()
merge_time_worst1000.append(mend1_worst1000 - mstart1_worst1000)
len_merge_worst1000.append(len(list_worst1000))

print(merge_time_worst1000[1])

plt.xlabel('Rozmiar danych') 
plt.ylabel('Czas') 
plt.plot(len_merge_worst1000, merge_time_worst1000, label ='merge Sort - przypadek pesymistyczny')

plt.grid() 
plt.legend() 
plt.show() 

# merge 1000
fig = pylab.figure(figsize=[6, 5])
pylab.plot(len_merge_best1000, merge_time_best1000, label = 'przypadek optymistyczny')
pylab.plot(len_merge1000, merge_time1000, label = 'przypadek średni')
pylab.plot(len_merge_worst1000, merge_time_worst1000, label = 'przypadek pesymistyczny')
pylab.legend(loc = 'best')
pylab.xlabel('rozmiar danych')
pylab.ylabel('czas')
pylab.title('Merge Sort\nrozmiar danych: 5000')
pylab.grid()
pylab.show()
# Out:
# 0.016892999999999603
# 0.017359000000002567
# 0.017991999999999564

# %%
# 100
"""BEST CASE"""
merge_time_best100 = [0]
len_merge_best100 = [0]

mstart1_best100 = time.clock()
merge(list_best100)
mend1_best100 = time.clock()
merge_time_best100.append(mend1_best100 - mstart1_best100)
len_merge_best100.append(len(list_best100))

print(merge_time_best100[1])

plt.xlabel('Rozmiar danych') 
plt.ylabel('Czas') 
plt.plot(len_merge_best100, merge_time_best100, label ='Merge Sort - przypadek optymistyczny') 
plt.grid() 
plt.legend() 
plt.show() 

"""AVERAGE CASE"""
merge_time100 = [0]
len_merge100 = [0]

mstart100 = time.clock()
merge(list_avg100)
mend100 = time.clock()
merge_time100.append(mend100 - mstart100)
len_merge100.append(len(list_avg100))

print(merge_time100[1])

plt.xlabel('Rozmiar danych') 
plt.ylabel('Czas') 
plt.plot(len_merge100, merge_time100, label ='Merge Sort - przypadek średni') 
plt.grid() 
plt.legend() 
plt.show() 

"""WORST CASE"""
merge_time_worst100 = [0]
len_merge_worst100 = [0]

mstart1_worst100 = time.clock()
merge(list_worst100)
mend1_worst100 = time.clock()
merge_time_worst100.append(mend1_worst100 - mstart1_worst100)
len_merge_worst100.append(len(list_worst100))

print(merge_time_worst100[1])

plt.xlabel('Rozmiar danych') 
plt.ylabel('Czas') 
plt.plot(len_merge_worst100, merge_time_worst100, label ='Merge Sort - przypadek pesymistyczny')

plt.grid() 
plt.legend() 
plt.show() 

# merge 100
fig = pylab.figure(figsize=[6, 5])
pylab.plot(len_merge_best100, merge_time_best100, label = 'przypadek optymistyczny')
pylab.plot(len_merge100, merge_time100, label = 'przypadek średni')
pylab.plot(len_merge_worst100, merge_time_worst100, label = 'przypadek pesymistyczny')
pylab.legend(loc = 'best')
pylab.xlabel('rozmiar danych')
pylab.ylabel('czas')
pylab.title('Merge Sort\nrozmiar danych: 250')
pylab.grid()
pylab.show()
# Out:
# 0.0006659999999989452
# 0.0005990000000011264
# 0.000641000000001668

# %%
def counting(lista):
    """O(n+k)"""
    n = len(lista)
    gora = max(lista)
    dol = min(lista)
    
    temp = [0] * (gora + 1)

    for el in lista:
        temp[el] += 1

    for el in range(1, gora+1):
        temp[el] += temp[el - 1]

    wynik = [0] * n
    i = n - 1

    while i >= 0: 
        wynik[temp[lista[i]]-1] = lista[i]
        temp[lista[i]] -= 1
        i -= 1      
    return wynik

# %%
# 10000
"""BEST CASE"""
counting_time_best10000 = [0]
len_counting_best10000 = [0]

cstart1_best10000 = time.clock()
counting(list_best10000)
cend1_best10000 = time.clock()
counting_time_best10000.append(cend1_best10000 - cstart1_best10000)
len_counting_best10000.append(len(list_best10000))

print(counting_time_best10000[1])

plt.xlabel('Rozmiar danych') 
plt.ylabel('Czas') 
plt.plot(len_counting_best10000, counting_time_best10000, label ='Counting Sort - przypadek optymistyczny') 
plt.grid() 
plt.legend() 
plt.show() 

"""AVERAGE CASE"""
counting_time10000 = [0]
len_counting10000 = [0]

cstart110000 = time.clock()
counting(list_avg10000)
cend110000 = time.clock()
counting_time10000.append(cend110000 - cstart110000)
len_counting10000.append(len(list_avg10000))

print(counting_time10000[1])

plt.xlabel('Rozmiar danych') 
plt.ylabel('Czas') 
plt.plot(len_counting10000, counting_time10000, label ='Counting Sort - przypadek średni') 
plt.grid() 
plt.legend() 
plt.show() 

"""WORST CASE"""
counting_time_worst10000 = [0]
len_counting_worst10000 = [0]

cstart1_worst10000 = time.clock()
counting(list_worst10000)
cend1_worst10000 = time.clock()
counting_time_worst10000.append(cend1_worst10000 - cstart1_worst10000)
len_counting_worst10000.append(len(list_worst10000))

print(counting_time_worst10000[1])

plt.xlabel('Rozmiar danych') 
plt.ylabel('Czas') 
plt.plot(len_counting_worst10000, counting_time_worst10000, label ='Counting Sort - przypadek pesymistyczny')

plt.grid() 
plt.legend() 
plt.show() 

# counting 10000
fig = pylab.figure(figsize=[6, 5])
pylab.plot(len_counting_best10000, counting_time_best10000, label = 'przypadek optymistyczny')
pylab.plot(len_counting10000, counting_time10000, label = 'przypadek średni')
pylab.plot(len_counting_worst10000, counting_time_worst10000, label = 'przypadek pesymistyczny')
pylab.legend(loc = 'best')
pylab.xlabel('rozmiar danych')
pylab.ylabel('czas')
pylab.title('Counting Sort\nrozmiar danych: 10000')
pylab.grid()
pylab.show()
# Out:
# 0.004691000000001111
# 0.00498100000000079
# 0.005040999999998519

# %%
# 1000
"""BEST CASE"""
counting_time_best1000 = [0]
len_counting_best1000 = [0]

cstart1_best1000 = time.clock()
counting(list_best1000)
cend1_best1000 = time.clock()
counting_time_best1000.append(cend1_best1000 - cstart1_best1000)
len_counting_best1000.append(len(list_best1000))

print(counting_time_best1000[1])

plt.xlabel('Rozmiar danych') 
plt.ylabel('Czas') 
plt.plot(len_counting_best1000, counting_time_best1000, label ='Counting Sort - przypadek optymistyczny') 
plt.grid() 
plt.legend() 
plt.show() 

"""AVERAGE CASE"""
counting_time1000 = [0]
len_counting1000 = [0]

cstart11000 = time.clock()
counting(list_avg1000)
cend11000 = time.clock()
counting_time1000.append(cend11000 - cstart11000)
len_counting1000.append(len(list_avg1000))

print(counting_time1000[1])

plt.xlabel('Rozmiar danych') 
plt.ylabel('Czas') 
plt.plot(len_counting1000, counting_time1000, label ='Counting Sort - przypadek średni') 
plt.grid() 
plt.legend() 
plt.show() 

"""WORST CASE"""
counting_time_worst1000 = [0]
len_counting_worst1000 = [0]

cstart1_worst1000 = time.clock()
counting(list_worst1000)
cend1_worst1000 = time.clock()
counting_time_worst1000.append(cend1_worst1000 - cstart1_worst1000)
len_counting_worst1000.append(len(list_worst1000))

print(counting_time_worst1000[1])

plt.xlabel('Rozmiar danych') 
plt.ylabel('Czas') 
plt.plot(len_counting_worst1000, counting_time_worst1000, label ='Counting Sort - przypadek pesymistyczny')

plt.grid() 
plt.legend() 
plt.show() 

# counting 1000
fig = pylab.figure(figsize=[6, 5])
pylab.plot(len_counting_best1000, counting_time_best1000, label = 'przypadek optymistyczny')
pylab.plot(len_counting1000, counting_time1000, label = 'przypadek średni')
pylab.plot(len_counting_worst1000, counting_time_worst1000, label = 'przypadek pesymistyczny')
pylab.legend(loc = 'best')
pylab.xlabel('rozmiar danych')
pylab.ylabel('czas')
pylab.title('Counting Sort\nrozmiar danych: 5000')
pylab.grid()
pylab.show()
# Out:
# 0.0021249999999994884
# 0.0023049999999997794
# 0.00244599999999906

# %%
# 100
"""BEST CASE"""
counting_time_best100 = [0]
len_counting_best100 = [0]

cstart1_best100 = time.clock()
counting(list_best100)
cend1_best100 = time.clock()
counting_time_best100.append(cend1_best100 - cstart1_best100)
len_counting_best100.append(len(list_best100))

print(counting_time_best100[1])

plt.xlabel('Rozmiar danych') 
plt.ylabel('Czas') 
plt.plot(len_counting_best100, counting_time_best100, label ='Counting Sort - przypadek optymistyczny') 
plt.grid() 
plt.legend() 
plt.show() 

"""AVERAGE CASE"""
counting_time100 = [0]
len_counting100 = [0]

cstart1100 = time.clock()
counting(list_avg100)
cend1100 = time.clock()
counting_time100.append(cend1100 - cstart1100)
len_counting100.append(len(list_avg100))

print(counting_time100[1])

plt.xlabel('Rozmiar danych') 
plt.ylabel('Czas') 
plt.plot(len_counting100, counting_time100, label ='Counting Sort - przypadek średni') 
plt.grid() 
plt.legend() 
plt.show() 

"""WORST CASE"""
counting_time_worst100 = [0]
len_counting_worst100 = [0]

cstart1_worst100 = time.clock()
counting(list_worst100)
cend1_worst100 = time.clock()
counting_time_worst100.append(cend1_worst100 - cstart1_worst100)
len_counting_worst100.append(len(list_worst100))

print(counting_time_worst100[1])

plt.xlabel('Rozmiar danych') 
plt.ylabel('Czas') 
plt.plot(len_counting_worst100, counting_time_worst100, label ='Counting Sort - przypadek pesymistyczny')

plt.grid() 
plt.legend() 
plt.show() 

# counting 100
fig = pylab.figure(figsize=[6, 5])
pylab.plot(len_counting_best100, counting_time_best100, label = 'przypadek optymistyczny')
pylab.plot(len_counting100, counting_time100, label = 'przypadek średni')
pylab.plot(len_counting_worst100, counting_time_worst100, label = 'przypadek pesymistyczny')
pylab.legend(loc = 'best')
pylab.xlabel('rozmiar danych')
pylab.ylabel('czas')
pylab.title('Counting Sort\nrozmiar danych: 250')
pylab.grid()
pylab.show()
# Out:
# 0.00013899999999722468
# 0.0001409999999992806
# 0.0001679999999986137

# %%
# 10000
# Three of them BEST
fig = pylab.figure(figsize=[6, 5])
pylab.plot(len_insertion_best10000, insertion_time_best10000, label = 'Insertion')
pylab.plot(len_merge_best10000, merge_time_best10000, label = 'Merge')
pylab.plot(len_counting_best10000, counting_time_best10000, label = 'Counting')
pylab.legend(loc = 'best')
pylab.xlabel('rozmiar danych')
pylab.ylabel('czas')
pylab.title('przypadek optymistyczny\nrozmiar danych: 10000')
pylab.grid()
pylab.show()

# Three of them AVG
fig = pylab.figure(figsize=[6, 5])
pylab.plot(len_insertion10000, insertion_time10000, label = 'Insertion')
pylab.plot(len_merge10000, merge_time10000, label = 'Merge')
pylab.plot(len_counting10000, counting_time10000, label = 'Counting')
pylab.legend(loc = 'best')
pylab.xlabel('rozmiar danych')
pylab.ylabel('czas')
pylab.title('przypadek średni\nrozmiar danych: 10000')
pylab.grid()
pylab.show()

# Three of them WORST
fig = pylab.figure(figsize=[6, 5])
pylab.plot(len_insertion_worst10000, insertion_time_worst10000, label = 'Insertion')
pylab.plot(len_merge_worst10000, merge_time_worst10000, label = 'Merge')
pylab.plot(len_counting_worst10000, counting_time_worst10000, label = 'Counting')
pylab.legend(loc = 'best')
pylab.xlabel('rozmiar danych')
pylab.ylabel('czas')
pylab.title('przypadek pesymistyczny\nrozmiar danych: 10000')
pylab.grid()
pylab.show()

# %%
# 1000
# Three of them BEST
fig = pylab.figure(figsize=[6, 5])
pylab.plot(len_insertion_best1000, insertion_time_best1000, label = 'Insertion')
pylab.plot(len_merge_best1000, merge_time_best1000, label = 'Merge')
pylab.plot(len_counting_best1000, counting_time_best1000, label = 'Counting')
pylab.legend(loc = 'best')
pylab.xlabel('rozmiar danych')
pylab.ylabel('czas')
pylab.title('przypadek optymistyczny\nrozmiar danych: 5000')
pylab.grid()
pylab.show()

# Three of them AVG
fig = pylab.figure(figsize=[6, 5])
pylab.plot(len_insertion1000, insertion_time1000, label = 'Insertion')
pylab.plot(len_merge1000, merge_time1000, label = 'Merge')
pylab.plot(len_counting1000, counting_time1000, label = 'Counting')
pylab.legend(loc = 'best')
pylab.xlabel('rozmiar danych')
pylab.ylabel('czas')
pylab.title('przypadek średni\nrozmiar danych: 5000')
pylab.grid()
pylab.show()

# Three of them WORST
fig = pylab.figure(figsize=[6, 5])
pylab.plot(len_insertion_worst1000, insertion_time_worst1000, label = 'Insertion')
pylab.plot(len_merge_worst1000, merge_time_worst1000, label = 'Merge')
pylab.plot(len_counting_worst1000, counting_time_worst1000, label = 'Counting')
pylab.legend(loc = 'best')
pylab.xlabel('rozmiar danych')
pylab.ylabel('czas')
pylab.title('przypadek pesymistyczny\nrozmiar danych: 5000')
pylab.grid()
pylab.show()

# %%
# 100
# Three of them BEST
fig = pylab.figure(figsize=[6, 5])
pylab.plot(len_insertion_best100, insertion_time_best100, label = 'Insertion')
pylab.plot(len_merge_best100, merge_time_best100, label = 'Merge')
pylab.plot(len_counting_best100, counting_time_best100, label = 'Counting')
pylab.legend(loc = 'best')
pylab.xlabel('rozmiar danych')
pylab.ylabel('czas')
pylab.title('przypadek optymistyczny\nrozmiar danych: 250')
pylab.grid()
pylab.show()

# Three of them AVG
fig = pylab.figure(figsize=[6, 5])
pylab.plot(len_insertion100, insertion_time100, label = 'Insertion')
pylab.plot(len_merge100, merge_time100, label = 'Merge')
pylab.plot(len_counting100, counting_time100, label = 'Counting')
pylab.legend(loc = 'best')
pylab.xlabel('rozmiar danych')
pylab.ylabel('czas')
pylab.title('przypadek średni\nrozmiar danych: 250')
pylab.grid()
pylab.show()

# Three of them WORST
fig = pylab.figure(figsize=[6, 5])
pylab.plot(len_insertion_worst100, insertion_time_worst100, label = 'Insertion')
pylab.plot(len_merge_worst100, merge_time_worst100, label = 'Merge')
pylab.plot(len_counting_worst100, counting_time_worst100, label = 'Counting')
pylab.legend(loc = 'best')
pylab.xlabel('rozmiar danych')
pylab.ylabel('czas')
pylab.title('przypadek pesymistyczny\nrozmiar danych: 250')
pylab.grid()
pylab.show()
